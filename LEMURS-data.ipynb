# %% [markdown]
# # LEMURS: Large-scale multi-detector ElectroMagnetic Universal Representation of Showers - data playground
#
# https://zenodo.org/records/17045562
#
# * $K$: number of events
#     - dataset FCCee\{ALLEGRO,CLD\}: ~100000
#     - dataset ODD: ~
#     - dataset Par04\{SciPb,SiW\}: ~
# * $V$: total number of voxels
#     - dataset *any: 6480, 45 layers (N), 16 ang splits (P), 9 rad splits (R)
# * $E_i,\quad i=1,\dots,K$: incident energy
# * $\alpha_i$: angle of entrance
# * $pid_j$: particle id
# * $\pmb{x}_{i}\in \mathbb{R}^V$ energy deposits across voxels
# * `showers` numpy array of shape (N, R, P)
# * `incident_energy` numpy array of shape (K, 1)
# * `incident_phi` numpy array of shape (K, 1)
# * `incident_theta` numpy array of shape (K, 1)
#
# $$
# \pmb{E} =
# \begin{bmatrix}
# E_1\\
# E_2\\
# \vdots\\
# E_K
# \end{bmatrix},
# \ \ \
# X =
# \begin{bmatrix}
# \ \pmb{x}^t_1 \\
# \ \pmb{x}^t_2 \\
# \vdots\\
# \ \pmb{x}^t_K
# \end{bmatrix}
# $$
#
# $$
# \pmb{x}_i = f(E_i,\ \alpha_i ;\ pid_j,\ geometry_j),\quad i=1,..,K,\quad j=1,...,4
# $$

# %%
# !git clone https://github.com/OzAmram/CaloChallenge.git
# Out:
# Cloning into 'CaloChallenge'...
# remote: Enumerating objects: 441, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 441 (delta 160), reused 140 (delta 140), pack-reused 271 (from 1)
# Receiving objects: 100% (441/441), 119.91 MiB | 8.88 MiB/s, done.
# Resolving deltas: 100% (244/244), done.

# %%
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt
import sys
sys.path.append('./CaloChallenge/code/')
import HighLevelFeatures as HLF
import os

# filename = "../calo-data/FCCeeALLEGRO/testing/LEMURS_FCCeeALLEGRO_gamma_1000events_5GeV_phi0.0_theta1.57.h5"
# filename = "/home/panos/turing/diffusion4sim/simulations/generated_1000events_Geo_SiW_E_50GeV_Phi_0.0_Theta_2.1.h5"
# filename = "/home/panos/turing/fastsim/generated_1000events_Geo_SiW_E_50GeV_Phi_0.0_Theta_1.57.h5"
filename="LEMURS_Par04SiW_gamma_100kEvents_1GeV1TeV_GPSflat_part1.h5"

i_idcs = None
# i_idcs = np.arange(0,100e3).astype(int)

with h5py.File(filename, "r") as f:
    print("Features in " + os.path.basename(filename) + ":", list(f.keys()))
    
    showers = f["showers"][i_idcs,:] if i_idcs is not None else f["showers"]
    showers = np.array(showers)
    incident_energies = f["incident_energy"][i_idcs] if i_idcs is not None else f["incident_energy"]
    incient_energies = np.array(incident_energies).reshape(-1,1)

print("Showers shape:", showers.shape)
print("Incident energies shape:", incident_energies.shape)

# i_idx = 0
# shower3d = showers[i_idx, :, :, :]
import pandas
df = pandas.DataFrame(showers.flatten())
df.describe()
# df.hist(bins=100)
# Out:
# Features in LEMURS_Par04SiW_gamma_100kEvents_1GeV1TeV_GPSflat_part1.h5: ['incident_energy', 'incident_phi', 'incident_theta', 'showers']
# Showers shape: (100000, 9, 16, 45)
# Incident energies shape: (100000,)
#                   0
# count  6.480000e+08
# mean   2.478303e+00
# std    9.570683e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.841201e-02
# 75%    8.250944e-01
# max    1.755065e+02

# %% [markdown]
# ## 3D scatter of a single shower

# %%
"""
requires
pip install --upgrade nbformat
pip install plotly
"""

import plotly.graph_objects as go

i_idx = 0
threshold = 1  # MeV — voxels below this are not displayed

shower3d = showers[i_idx, :, :, :]

num_rad_splits, num_ang_splits, num_layers = shower3d.shape

# bin centers
R   = np.arange(num_rad_splits)
PHI = np.linspace(0, 2*np.pi, num_ang_splits, endpoint=False)
Z   = np.arange(num_layers)

r, phi, z = np.meshgrid(R, PHI, Z, indexing='ij')

# Cartesian conversion
x = r * np.cos(phi)
y = r * np.sin(phi)

# apply threshold
mask = shower3d.flatten() >= threshold
vals = shower3d.flatten()[mask]

fig = go.Figure(
    data=[
        go.Scatter3d(
            x=x.flatten()[mask],
            y=y.flatten()[mask],
            z=z.flatten()[mask],
            mode='markers',
            marker=dict(
                size=5,
                opacity=1,
                colorscale='greens',
                color=np.log(vals + 1),
                cmin=0,
                cmax=np.log(shower3d.max() + 1),
                symbol='square',
                showscale=True,
                colorbar=dict(
                    title="log(MeV+1)",
                    thickness=8,
                    len=0.35,
                    x=1.0,
                ),
            ),
        ),
        
        # X-axis line
        go.Scatter3d(
            x=[x.flatten().min(), x.flatten().max()],
            y=[0, 0], z=[0, 0],
            mode='lines', line=dict(color='red', width=4), name='X-axis'
        ),
        # Y-axis line
        go.Scatter3d(
            x=[0, 0],
            y=[y.flatten().min(), y.flatten().max()], z=[0, 0],
            mode='lines', line=dict(color='blue', width=4), name='Y-axis'
        ),
        # Z-axis line
        go.Scatter3d(
            x=[0, 0], y=[0, 0],
            z=[z.flatten().min(), z.flatten().max()],
            mode='lines', line=dict(color='green', width=4), name='Z-axis'
        )
    ]
)

fig.update_layout(
    title=dict(
        text=f"Shower #{i_idx} — E<sub>inc</sub> = {incident_energies[i_idx]/1e3:.2f} GeV  | max(E) = {showers[i_idx].max():.2f} MeV | threshold = {threshold/1e3} GeV",
        x=0.5,
        xanchor='center',
    ),
    scene=dict(
        xaxis_title="X",
        yaxis_title="Y",
        zaxis_title="Z",
        xaxis=dict(title="X", backgroundcolor="rgba(0,0,0,0)", showbackground=True, gridcolor="lightgray"),
        yaxis=dict(title="Y", backgroundcolor="rgba(0,0,0,0)", showbackground=True, gridcolor="lightgray"),
        zaxis=dict(title="Z", backgroundcolor="rgba(0,0,0,0)", showbackground=True, gridcolor="lightgray"),
        camera=dict(
            up=dict(x=0, y=0.1, z=0),
            center=dict(x=0, y=0, z=0),
            eye=dict(x=-1.5, y=1.5, z=-1.8)
        )
    ),
    height=1000,
    width=1500,
)

fig.show()

# %%
z_profiles = showers.sum(axis=(1,2))
fig,ax = plt.subplots(1,2,figsize=(20,6))
fig.suptitle('Z-profiles: ' + filename + ' | slice: '+str(i_idcs))
ax[0].plot(z_profiles[:1000].T,'k-',lw=0.1)
ax[1].semilogy(z_profiles[:1000].T,'k-',lw=0.1)
for a in ax: a.grid('auto');
ax[0].set_title('MeV');
ax[1].set_title('log(MeV)');

# %% [markdown]
# # Layer Mesh3d histograms
# Requested figure by @arampatzis

# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# --- Example data ---
num_rad_splits, num_ang_splits, num_layers = shower3d.shape

R   = np.arange(num_rad_splits)
PHI = np.linspace(0, 2*np.pi, num_ang_splits, endpoint=False)
r, phi = np.meshgrid(R, PHI, indexing='ij')
x = r * np.cos(phi)
y = r * np.sin(phi)
z = np.zeros_like(x)

# --- Choose layers to display ---
layers = list(range(15))  # display all layers
n_cols = 5                        # number of columns per row
n_rows = (len(layers) + n_cols - 1) // n_cols  # ceil division

# --- Create subplot grid ---
specs = [[{'type': 'scene'} for _ in range(n_cols)] for _ in range(n_rows)]
fig = make_subplots(
    rows=n_rows,
    cols=n_cols,
    specs=specs,
    subplot_titles=[f"Layer {i}" for i in layers],
    horizontal_spacing=0.02,
    vertical_spacing=0.02
)

# --- Add each layer to the appropriate subplot ---
for idx, layer_idx in enumerate(layers):
    row = idx // n_cols + 1
    col = idx % n_cols + 1
    shower2d = shower3d[:, :, layer_idx]

    fig.add_trace(
        go.Mesh3d(
            x=x.flatten(),
            y=y.flatten(),
            z=shower2d.flatten(),
            intensity=shower2d.flatten(),
            opacity=0.7,
            showscale=(idx == 14),
            colorbar=dict(
                title="Energy (MeV)",
                orientation="h",
                x=0.5, y=-0.2,
                xanchor="center",
                yanchor="top"
            )
        ),
        row=row,
        col=col,
    )

# --- Adjust layout ---
fig.update_layout(
    height=300 * n_rows,   # taller for multiple rows
    width=300 * n_cols,    # width per column
    margin=dict(l=0, r=0, t=30, b=0)
)

# Keep aspect ratio consistent
for idx in range(1, len(layers)+1):
    fig.update_layout({
        f'scene{idx if idx>1 else ""}': dict(
            xaxis=dict(title='',showticklabels=False),
            yaxis=dict(title='',showticklabels=False),
            zaxis=dict(title='',showticklabels=False),
            aspectmode='manual',
            aspectratio=dict(x=1, y=1, z=0.8),
        )
    })

fig.show()
# fig.write_image("figure.png", width=2000, height=1500, scale=3)
